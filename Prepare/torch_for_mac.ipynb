# %%
# %brew install cask
# %brew install --cask miniforge
# %conda init zsh

# %%
# %conda install -c conda-forge pytorch
# Out:
# Channels:
#  - conda-forge
#  - defaults
# Platform: osx-arm64
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/homebrew/anaconda3/envs/torch
#
#   added / updated specs:
#     - pytorch
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     filelock-3.13.3            |     pyhd8ed1ab_0          15 KB  conda-forge
#     fsspec-2024.3.1            |     pyhca7485f_0         126 KB  conda-forge
#     libtorch-2.1.2             |cpu_generic_hff38252_3        27.0 MB  conda-forge
#     llvm-openmp-18.1.2         |       hcd81f8e_0         270 KB  conda-forge
#     markupsafe-2.1.5           |  py312he37b823_0          26 KB  conda-forge
#     numpy-1.26.4               |  py312h8442bc7_0         5.8 MB  conda-forge
#     pytorch-2.1.2              |cpu_generic_py312hb841a54_3        47.6 MB  conda-forge
# ...

# %%
import torch
x = torch.rand(5, 3)
print(x)
# Out:
# tensor([[0.3339, 0.1644, 0.1977],
#         [0.7921, 0.8380, 0.3152],
#         [0.7540, 0.4107, 0.3323],
#         [0.0106, 0.3101, 0.9467],
#         [0.4944, 0.0234, 0.6806]])
